# %%
import pandas as pd

# %%
df1 = pd.read_excel('trailBook1.xlsx')
df1
# Out:
#                                                  insta
# 0                                      biswajeetyadavv
# 1                                      Biswajeet Yadav
# 2                                                  NaN
# 3                                           jb_y_a_s_h
# 4                                     Jashobant Bag ⚡️
# 5                                            Following
# 6                                                  NaN
# 7                                       yadav_sudipta_
# 8                                              SUDIPTA
# 9                                            Following
# 10                                                 NaN
# 11                                         swayam_nyk1
# 12                                             swayam.
# 13                                           Following
# 14                                                 NaN
# 15                                            adtmhr16
# ...

# %%
df2 = pd.read_excel('Book1.xlsx')
df2
# Out:
#                      Username
# 0               nancytyagi___
# 1          __.__nilakshi__.__
# 2          agoodwitchofficial
# 3                 thekurtaguy
# 4                  brut.india
# 5           vivacious_varenya
# 6                 foodpharmer
# 7                   archeepal
# 8                    _sudi.pa
# 9              meer_mehvish41
# 10               i_mvaishnavi
# 11          handmadebyvandana
# 12          _.harleenkaurrrr_
# 13             trupti_rani.26
# 14             pallavi_sabar_
# 15                 tejuu_3011
# 16                  snehag138
# 17            himanshu_dulani
# 18          shresh_bacchashya
# 19            _.heyy_prachi._
# 20                 simii._.05
# 21               gopiikamohan
# 22               nupursiinghh
# 23             jhanviibhatiaa
# 24                _aleeee15__
# 25            __bebo._.jaan__
# 26           sanket_panchal25
# 27                    mxvika_
# 28           _v.pratikshya_._
# 29                   vrede_01
# ...

# %%
df2.shape
# Out:
# (295, 1)

# %%
import pandas as pd

# Assuming df1 and df2 are your DataFrames

# Handle potential differences in index and columns
df_merged = df1.merge(df2, how='outer', indicator=True)

# Identify rows present only in df2 (new values)
new_values = df_merged[df_merged['_merge'] == 'right_only'][df2.columns]

# Optional: Reset index if needed
if not new_values.index.equals(df2.index):
    new_values = new_values.reset_index(drop=True)

print(new_values)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[25], line 6
#       1 import pandas as pd
#       3 # Assuming df1 and df2 are your DataFrames
#       4
#       5 # Handle potential differences in index and columns
# ----> 6 df_merged = df1.merge(df2, how='outer', indicator=True)
#       8 # Identify rows present only in df2 (new values)
#       9 new_values = df_merged[df_merged['_merge'] == 'right_only'][df2.columns]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
# ...

# %%
def delete_words_by_char(text, char):
  """
  This function removes words containing a specific character from a string.

  Args:
      text: The original string.
      char: The character to use as a delimiter.

  Returns:
      A new string with words containing the character removed.
  """
  new_text = ""
  start_index = 0
  for i in range(len(text)):
    if text[i] == char:
      # Add the substring from the previous character to the current one (excluding char)
      new_text += text[start_index:i]
      start_index = i + 1
  # Add the last word if it doesn't contain the character
  new_text += text[start_index:]
  return new_text

text = "This is a string with some words. Here's another word"
char = ' '  # Delete words based on spaces

new_text = delete_words_by_char(text, char)
print(new_text)  # Output: ThisisastringwithsomeswordsHeresanotherword
# Out:
# Thisisastringwithsomewords.Here'sanotherword

# %%
df1
