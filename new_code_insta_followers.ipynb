# %%
import pandas as pd

# %%
dfold = pd.read_excel("new.xlsx")
dfold
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\reader\workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 dfold = pd.read_excel("new.xlsx")
#       2 dfold
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
dfold.she
# Out:
# (500, 7)

# %%
dfold.columns
# Out:
# Index(['User ID', 'Username', 'Fullname', 'Followed by you', 'Is verified',
#        'Profile URL', 'Avatar URL'],
#       dtype='object')

# %%
dfold
# Out:
#                             User ID                  Username  Fullname  \
# 495673196             illustratejoy                    Maddie      True
# 8410881                alanritchson             Alan Ritchson      True
# 524670187       safarnamaa.patrowww              Sushil Patro      True
# 25227752471             lpu.confess      LPU Confession Page❤      True
# 330947260             omarenfedaque            Omar Enfedaque      True
# ...                             ...                       ...       ...
# 57384506331               gymnash96  Gym | Fitness | Training      True
# 2136138769     roaming_nutritionist               Ambika Dutt      True
# 3962421069         commando_mindset              Arun Sangwan      True
# 59819577328  _akshat_singh_rajput._              AKSHAT SINGH      True
# 5397270104           nikhill.siingh              Nikhil Singh      True
#
#              Followed by you  \
# 495673196              False
# 8410881                 True
# ...

# %%
df = dfold.drop('Avatar URL',axis =1)

# %%
df
# Out:
#                             User ID                  Username  Fullname  \
# 495673196             illustratejoy                    Maddie      True
# 8410881                alanritchson             Alan Ritchson      True
# 524670187       safarnamaa.patrowww              Sushil Patro      True
# 25227752471             lpu.confess      LPU Confession Page❤      True
# 330947260             omarenfedaque            Omar Enfedaque      True
# ...                             ...                       ...       ...
# 57384506331               gymnash96  Gym | Fitness | Training      True
# 2136138769     roaming_nutritionist               Ambika Dutt      True
# 3962421069         commando_mindset              Arun Sangwan      True
# 59819577328  _akshat_singh_rajput._              AKSHAT SINGH      True
# 5397270104           nikhill.siingh              Nikhil Singh      True
#
#              Followed by you  \
# 495673196              False
# 8410881                 True
# ...

# %%
df['User ID']
# Out:
# 495673196               illustratejoy
# 8410881                  alanritchson
# 524670187         safarnamaa.patrowww
# 25227752471               lpu.confess
# 330947260               omarenfedaque
#                         ...
# 57384506331                 gymnash96
# 2136138769       roaming_nutritionist
# 3962421069           commando_mindset
# 59819577328    _akshat_singh_rajput._
# 5397270104             nikhill.siingh
# Name: User ID, Length: 500, dtype: object

# %%
df['Username']
# Out:
# 495673196                        Maddie
# 8410881                   Alan Ritchson
# 524670187                  Sushil Patro
# 25227752471        LPU Confession Page❤
# 330947260                Omar Enfedaque
#                          ...
# 57384506331    Gym | Fitness | Training
# 2136138769                  Ambika Dutt
# 3962421069                 Arun Sangwan
# 59819577328                AKSHAT SINGH
# 5397270104                 Nikhil Singh
# Name: Username, Length: 500, dtype: object
